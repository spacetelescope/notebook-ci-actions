# %% [markdown]
# # Basic Validation Test Notebook
#
# This notebook demonstrates basic functionality for testing the CI/CD pipeline.
# It includes simple Python operations that should execute successfully.

# %%
# Import basic libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

print("Basic libraries imported successfully!")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
# Out:
# Basic libraries imported successfully!
# NumPy version: 1.24.3
# Pandas version: 2.1.4

# %%
# Create simple test data
data = np.random.randn(100)
df = pd.DataFrame({
    'values': data,
    'squared': data**2,
    'index': range(100)
})

print(f"Created DataFrame with {len(df)} rows")
print("\nFirst 5 rows:")
print(df.head())
# Out:
# Created DataFrame with 100 rows
#
# First 5 rows:
#      values   squared  index
# 0 -0.031219  0.000975      0
# 1  0.590626  0.348839      1
# 2  1.458132  2.126148      2
# 3  1.472912  2.169468      3
# 4  0.154756  0.023949      4

# %%
# Create a simple plot
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.hist(df['values'], bins=20, alpha=0.7)
plt.title('Distribution of Random Values')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.scatter(df['values'], df['squared'], alpha=0.6)
plt.title('Values vs Squared Values')
plt.xlabel('Original Value')
plt.ylabel('Squared Value')

plt.tight_layout()
plt.show()

print("✅ Basic validation test completed successfully!")
# Out:
# ✅ Basic validation test completed successfully!

# %% [markdown]
# ## Summary
#
# This notebook demonstrates:
# - ✅ Library imports (numpy, pandas, matplotlib)
# - ✅ Data creation and manipulation
# - ✅ Basic plotting functionality
# - ✅ Successful execution without errors
#
# This notebook should pass validation and execution tests in the CI/CD pipeline.
